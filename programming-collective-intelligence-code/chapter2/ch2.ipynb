# %%
import recommendations
reload(recommendations)
# Out:
# <module 'recommendations' from 'recommendations.pyc'>

# %%
recommendations.critics
# Out:
# {'Claudia Puig': {'Just My Luck': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 4.0,
#   'The Night Listener': 4.5,
#   'You, Me and Dupree': 2.5},
#  'Gene Seymour': {'Just My Luck': 1.5,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Jack Matthews': {'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 5.0,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 3.5},
#  'Lisa Rose': {'Just My Luck': 3.0,
#   'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.5,
#   'Superman Returns': 3.5,
#   'The Night Listener': 3.0,
#   'You, Me and Dupree': 2.5},
#  'Michael Phillips': {'Lady in the Water': 2.5,
#   'Snakes on a Plane': 3.0,
#   'Superman Returns': 3.5,
#   'The Night Listener': 4.0},
#  'Mick LaSalle': {'Just My Luck': 2.0,
#   'Lady in the Water': 3.0,
#   'Snakes on a Plane': 4.0,
#   'Superman Returns': 3.0,
# ...

# %%
from recommendations import critics

# %%
critics['Michael Phillips']
# Out:
# {'Lady in the Water': 2.5,
#  'Snakes on a Plane': 3.0,
#  'Superman Returns': 3.5,
#  'The Night Listener': 4.0}

# %%
recommendations.sim_distance(critics,'Lisa Rose','Gene Seymour')
# Out:
# 0.14814814814814814

# %%
recommendations.sim_pearson(critics,'Lisa Rose','Gene Seymour')
# Out:
# 0.39605901719066977

# %%
si={}
for item in critics['Lisa Rose']: 
    if item in critics['Gene Seymour']: si[item]=1
si
# Out:
# {'Just My Luck': 1,
#  'Lady in the Water': 1,
#  'Snakes on a Plane': 1,
#  'Superman Returns': 1,
#  'The Night Listener': 1,
#  'You, Me and Dupree': 1}

# %%
recommendations.topMatches(recommendations.critics,'Toby',n=5)
# Out:
# [(0.9912407071619299, 'Lisa Rose'),
#  (0.9244734516419049, 'Mick LaSalle'),
#  (0.8934051474415647, 'Claudia Puig'),
#  (0.66284898035987, 'Jack Matthews'),
#  (0.38124642583151164, 'Gene Seymour')]

# %%
recommendations.getRecommendations(recommendations.critics,'Toby',recommendations.sim_distance)
# Out:
# [(3.5002478401415877, 'The Night Listener'),
#  (2.7561242939959363, 'Lady in the Water'),
#  (2.461988486074374, 'Just My Luck')]

# %%
recommendations.getRecommendations(recommendations.critics,'Toby')
# Out:
# [(3.3477895267131013, 'The Night Listener'),
#  (2.8325499182641614, 'Lady in the Water'),
#  (2.5309807037655645, 'Just My Luck')]

# %%
x=critics['Michael Phillips']

# %%
x.setdefault('Lady in the Water',0)
# Out:
# 2.5

# %%
movies=recommendations.transformPrefs(recommendations.critics)

# %%
recommendations.topMatches(movies,'Superman Returns')
# Out:
# [(0.6579516949597695, 'You, Me and Dupree'),
#  (0.4879500364742689, 'Lady in the Water'),
#  (0.11180339887498941, 'Snakes on a Plane'),
#  (-0.1798471947990544, 'The Night Listener'),
#  (-0.42289003161103106, 'Just My Luck')]

# %%
recommendations.getRecommendations(movies,'Just My Luck')
# Out:
# [(4.0, 'Michael Phillips'), (3.0, 'Jack Matthews')]

# %%
itemsim=recommendations.calculateSimilarItems(recommendations.critics)
itemsim
# Out:
# {'Just My Luck': [(0.2222222222222222, 'Lady in the Water'),
#   (0.18181818181818182, 'You, Me and Dupree'),
#   (0.15384615384615385, 'The Night Listener'),
#   (0.10526315789473684, 'Snakes on a Plane'),
#   (0.06451612903225806, 'Superman Returns')],
#  'Lady in the Water': [(0.4, 'You, Me and Dupree'),
#   (0.2857142857142857, 'The Night Listener'),
#   (0.2222222222222222, 'Snakes on a Plane'),
#   (0.2222222222222222, 'Just My Luck'),
#   (0.09090909090909091, 'Superman Returns')],
#  'Snakes on a Plane': [(0.2222222222222222, 'Lady in the Water'),
#   (0.18181818181818182, 'The Night Listener'),
#   (0.16666666666666666, 'Superman Returns'),
#   (0.10526315789473684, 'Just My Luck'),
#   (0.05128205128205128, 'You, Me and Dupree')],
#  'Superman Returns': [(0.16666666666666666, 'Snakes on a Plane'),
#   (0.10256410256410256, 'The Night Listener'),
#   (0.09090909090909091, 'Lady in the Water'),
#   (0.06451612903225806, 'Just My Luck'),
# ...

# %%
recommendations.sim_pearson(recommendations.critics,'Claudia Puig','Gene Seymour')
# Out:
# 0.31497039417435607

# %%
[(recommendations.sim_pearson(recommendations.critics,'Claudia Puig',other),other)
        for other in recommendations.critics if other != 'Claudia Puig']
# Out:
# [(0.02857142857142857, 'Jack Matthews'),
#  (0.5669467095138411, 'Mick LaSalle'),
#  (0.5669467095138396, 'Lisa Rose'),
#  (0.8934051474415647, 'Toby'),
#  (0.31497039417435607, 'Gene Seymour'),
#  (1.0, 'Michael Phillips')]

# %%
b=recommendations.getRecommendedItems(recommendations.critics,itemsim,'Toby')
b.sort()
b
# Out:
# [(2.4730878186968837, 'Lady in the Water'),
#  (2.5983318700614575, 'Just My Luck'),
#  (3.182634730538922, 'The Night Listener')]

# %%
recommendations.critics['Toby']
# Out:
# {'Snakes on a Plane': 4.5, 'Superman Returns': 4.0, 'You, Me and Dupree': 1.0}

# %%
lm = recommendations.loadMovieLens('data/movielens')

# %%
len(lm)
# Out:
# 943

# %%
lm.keys()
# Out:
# ['344',
#  '345',
#  '346',
#  '347',
#  '340',
#  '341',
#  '342',
#  '343',
#  '810',
#  '811',
#  '812',
#  '813',
#  '348',
#  '349',
#  '816',
#  '817',
#  '595',
#  '719',
#  '718',
#  '717',
#  '716',
#  '715',
#  '714',
#  '713',
#  '712',
#  '711',
#  '710',
#  '915',
#  '914',
#  '606',
#  '917',
#  '594',
#  '736',
#  '916',
#  '911',
#  '619',
#  '910',
#  '913',
#  '298',
#  '299',
#  '296',
#  '297',
#  '294',
#  '295',
#  '292',
#  '293',
#  '290',
#  '291',
#  '591',
#  '590',
#  '593',
#  '592',
#  '199',
#  '198',
#  '597',
#  '596',
#  '195',
#  '194',
#  '197',
#  '196',
#  '191',
#  '190',
#  '193',
#  '192',
#  '270',
#  '271',
#  '272',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '738',
#  '524',
#  '525',
#  '526',
#  '527',
#  '520',
#  '521',
#  '522',
#  '523',
#  '599',
#  '528',
#  '529',
#  '449',
#  '448',
#  '443',
#  '442',
#  '441',
#  '440',
#  '447',
#  '446',
#  '445',
#  '444',
#  '108',
#  '109',
#  '102',
#  '103',
# ...

# %%
lm.get('1')
# Out:
# {'101 Dalmatians (1996)': 2.0,
#  '12 Angry Men (1957)': 5.0,
#  '20,000 Leagues Under the Sea (1954)': 3.0,
#  '2001: A Space Odyssey (1968)': 4.0,
#  'Abyss, The (1989)': 3.0,
#  'Ace Ventura: Pet Detective (1994)': 3.0,
#  'Air Bud (1997)': 1.0,
#  'Akira (1988)': 4.0,
#  'Aladdin (1992)': 4.0,
#  'Alien (1979)': 5.0,
#  'Aliens (1986)': 5.0,
#  'All Dogs Go to Heaven 2 (1996)': 1.0,
#  'Amadeus (1984)': 5.0,
#  'Angels and Insects (1995)': 4.0,
#  "Antonia's Line (1995)": 5.0,
#  'Apocalypse Now (1979)': 3.0,
#  'Apollo 13 (1995)': 4.0,
#  'Aristocats, The (1970)': 2.0,
#  'Army of Darkness (1993)': 4.0,
#  'Austin Powers: International Man of Mystery (1997)': 4.0,
#  'Babe (1995)': 1.0,
#  'Back to the Future (1985)': 5.0,
#  'Bad Boys (1995)': 2.0,
#  'Basic Instinct (1992)': 3.0,
#  'Batman & Robin (1997)': 1.0,
#  'Batman Forever (1995)': 1.0,
#  'Batman Returns (1992)': 1.0,
#  'Beavis and Butt-head Do America (1996)': 3.0,
#  'Bedknobs and Broomsticks (1971)': 2.0,
# ...

# %%
recommendations.getRecommendations(lm, '87')[0:30]
# Out:
# [(5.0, 'They Made Me a Criminal (1939)'),
#  (5.0, 'Star Kid (1997)'),
#  (5.0, 'Santa with Muscles (1996)'),
#  (5.0, 'Saint of Fort Washington, The (1993)'),
#  (5.0, 'Marlene Dietrich: Shadow and Light (1996) '),
#  (5.0, 'Great Day in Harlem, A (1994)'),
#  (5.0, 'Entertaining Angels: The Dorothy Day Story (1996)'),
#  (5.0, 'Boys, Les (1997)'),
#  (4.89884443128923, 'Legal Deceit (1997)'),
#  (4.815019082242709, 'Letter From Death Row, A (1998)'),
#  (4.7321082983941425, 'Hearts and Minds (1996)'),
#  (4.696244466490867, 'Pather Panchali (1955)'),
#  (4.652397061026758, 'Lamerica (1994)'),
#  (4.538723693474813, 'Leading Man, The (1996)'),
#  (4.535081339106103, 'Mrs. Dalloway (1997)'),
#  (4.532337612572981, 'Innocents, The (1961)'),
#  (4.527998574747079, 'Casablanca (1942)'),
#  (4.510270149719864, 'Everest (1998)'),
#  (4.493967755428439, 'Dangerous Beauty (1998)'),
#  (4.485151301801342, 'Wallace & Gromit: The Best of Aardman Animation (1996)'),
# ...

# %%
itemsim = recommendations.calculateSimilarItems(lm, n=50)
# Out:
# 100 / 1664
# 200 / 1664
# 300 / 1664
# 400 / 1664
# 500 / 1664
# 800 / 1664

# %%
recommendations.getRecommendedItems(lm, itemsim, '87')[0:30]
